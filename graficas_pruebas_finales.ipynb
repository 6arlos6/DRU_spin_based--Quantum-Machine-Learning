# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Resultados prueba final

# %%
path_data_full = "/content/drive/MyDrive/Notebook_tesis_def/DATA/Save_excel_1q_iris_3_3(18).xlsx"

# %%
df_final = pd.read_excel(path_data_full)
df_final.head()
# Out:
#    accuracy_0  0_0_0_precision  0_0_0_recall  0_0_0_f1-score  0_0_0_support  \
# 0    0.155556         0.263158      0.263158        0.263158             19
# 1    0.933333         1.000000      1.000000        1.000000             19
# 2    0.155556         0.263158      0.263158        0.263158             19
# 3    0.733333         0.933333      0.736842        0.823529             19
# 4    0.466667         0.529412      0.473684        0.500000             19
#
#    1_0_1_precision  1_0_1_recall  1_0_1_f1-score  1_0_1_support  \
# 0         0.000000      0.000000        0.000000             13
# 1         0.857143      0.923077        0.888889             13
# 2         0.000000      0.000000        0.000000             13
# 3         0.818182      0.692308        0.750000             13
# 4         0.500000      0.538462        0.518519             13
#
#    2_0_2_precision  ...  Noise  N_qubits  tf_noise  std_noide    B0  B1  \
# ...

# %%
plt.figure()

for f in df_final["f_loss"].unique():
  df_f_loss = df_final[df_final["f_loss"] == f]
  #for noise_ in df_f_loss["std_noide"]:
  #df_f_loss_noise = df_f_loss[df_f_loss["std_noide"] == noise_]
  #plt.scatter(df_f_loss_noise["num_layers"], df_f_loss_noise["accuracy_0"])
  plt.scatter(df_f_loss["num_layers"], df_f_loss["accuracy_0"])
  plt.grid()
  plt.title(f"f_loss = {f} and noise = {1}")
  plt.show()

# %% [markdown]
# # Grafica 1

# %%
import matplotlib.pyplot as plt
import seaborn as sns



# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0", hue="f_loss", data=df_final, palette='Set1')

# Mostrar el plot
plt.title('Scatter Plot de A vs B con colores basados en C')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["T2"] == 0.000023]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0", hue="f_loss",size='Noise', data=df_final_v2, palette='Set1', sizes=(20, 200))

# Mostrar el plot
plt.title(f'Accuracy with T2 = {23} u [s]')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["T2"] == 0.000006]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
# , hue='C', size='Tamaño', data=df, palette='Set1', sizes=(20, 200)
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0", hue="f_loss",size='Noise', data=df_final_v2, palette='Set1', sizes=(20, 200))

# Mostrar el plot
plt.title(f'Accuracy with T2 = {6} u [s]')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["std_noide"] == 0]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0", hue="f_loss",size='Noise', data=df_final_v2, palette='Set1', sizes=(20, 200))

# Mostrar el plot
plt.title(f'Accuracy with $\sigma$ = {23} 0 [T]')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["std_noide"] == 0.001]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0", hue="f_loss",size='Noise', data=df_final_v2, palette='Set1', sizes=(20, 200))

# Mostrar el plot
plt.title(f'Accuracy with $\sigma$ =  0.001 [T]')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["std_noide"] == 0.1]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0", hue="f_loss",size='Noise', data=df_final_v2, palette='Set1', sizes=(20, 200))

# Mostrar el plot
plt.title(f'Accuracy with $\sigma$ =  0.1 [T]')
plt.show()

# %% [markdown]
# # MACRO f1

# %%
macro avg_0_macro avg_f1-score

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["T2"] == 0.000023]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="macro avg_0_macro avg_f1-score", hue="f_loss",size='Noise', data=df_final_v2, palette='Set1', sizes=(20, 200))

# Mostrar el plot
plt.title('Scatter Plot de A vs B con colores basados en C')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["T2"] == 0.000006]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="macro avg_0_macro avg_f1-score", hue="f_loss",size='Noise', data=df_final_v2, palette='Set1', sizes=(20, 200))

# Mostrar el plot
plt.title('Scatter Plot de A vs B con colores basados en C')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["std_noide"] == 0]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="macro avg_0_macro avg_f1-score", hue="f_loss",size='Noise', data=df_final_v2, palette='Set1', sizes=(20, 200))

# Mostrar el plot
plt.title('Scatter Plot de A vs B con colores basados en C')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["std_noide"] == 0.1]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="macro avg_0_macro avg_f1-score", hue="f_loss",size='Noise', data=df_final_v2, palette='Set1', sizes=(20, 200))

# Mostrar el plot
plt.title('Scatter Plot de A vs B con colores basados en C')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["std_noide"] == 0.001]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="macro avg_0_macro avg_f1-score", hue="f_loss",size='Noise', data=df_final_v2, palette='Set1', sizes=(20, 200))

# Mostrar el plot
plt.title('Scatter Plot de A vs B con colores basados en C')
# Out:
# Text(0.5, 1.0, 'Scatter Plot de A vs B con colores basados en C')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[(df_final["std_noide"] == 0) & (df_final["T2"] == 0.000006)]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="macro avg_0_macro avg_f1-score", hue="f_loss",size='Noise', data=df_final_v2, palette='Set1', sizes=(20, 200))

# Mostrar el plot
plt.title('Scatter Plot de A vs B con colores basados en C')
# Out:
# Text(0.5, 1.0, 'Scatter Plot de A vs B con colores basados en C')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#df_final_v2 = df_final[(df_final["std_noide"] == 0) & (df_final["T2"] == 0.000006)]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="std_noide", y="macro avg_0_macro avg_f1-score", hue="f_loss",size='Noise', data=df_final, palette='Set1', sizes=(20, 200))

# Mostrar el plot
plt.title('Scatter Plot de A vs B con colores basados en C')
# Out:
# Text(0.5, 1.0, 'Scatter Plot de A vs B con colores basados en C')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#df_final_v2 = df_final[(df_final["std_noide"] == 0) & (df_final["T2"] == 0.000006)]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="T2", y="macro avg_0_macro avg_f1-score", hue="f_loss",size='Noise', data=df_final, palette='Set1', sizes=(20, 200))

# Mostrar el plot
plt.title('Scatter Plot de A vs B con colores basados en C')
# Out:
# Text(0.5, 1.0, 'Scatter Plot de A vs B con colores basados en C')

# %% [markdown]
# # Resultado entrenamiento 1 qubit

# %%
path_data_full_1q = "/content/drive/MyDrive/Notebook_tesis_def/DATA/resultados_clasificacion_1q_iris_3_3.xlsx"

# %%
df_final_1q = pd.read_excel(path_data_full_1q)
df_final_1q.head()
# Out:
#    accuracy_0  0_0_0_precision  0_0_0_recall  0_0_0_f1-score  0_0_0_support  \
# 0    0.966667         1.000000             1        1.000000             10
# 1    0.933333         1.000000             1        1.000000             10
# 2    0.900000         0.833333             1        0.909091             10
# 3    0.333333         0.333333             1        0.500000             10
# 4    0.866667         0.833333             1        0.909091             10
#
#    1_0_1_precision  1_0_1_recall  1_0_1_f1-score  1_0_1_support  \
# 0         0.900000           1.0        0.947368              9
# 1         0.818182           1.0        0.900000              9
# 2         0.900000           1.0        0.947368              9
# 3         0.000000           0.0        0.000000              9
# 4         0.818182           1.0        0.900000              9
#
#    2_0_2_precision  ...  weighted avg_0_weighted avg_precision  \
# ...

# %%
for f in df_final_1q["f_loss"].unique():
  df_f_loss = df_final_1q[df_final_1q["f_loss"] == f]
  plt.figure()
  for noise_ in df_f_loss["Noise"].unique():
    df_f_loss_noise = df_f_loss[df_f_loss["Noise"] == noise_]
    plt.plot(df_f_loss_noise["N_layers"], df_f_loss_noise["accuracy_0"],'-o', label = f"noise = {noise_}")
  plt.title(f"f_loss = {f}")
  plt.legend()
  plt.grid()
  plt.show()

# %% [markdown]
# # Resultado entrenamiento 2 qubit - sin entrelazamiento

# %%
path_data_full_1q = "/content/drive/MyDrive/Notebook_tesis_def/DATA/resultados_clasificacion_2q_wo_entanglement.xlsx"

# %%
df_final_1q = pd.read_excel(path_data_full_1q)
df_final_1q.head()
# Out:
#    accuracy_0  0_0_0_precision  0_0_0_recall  0_0_0_f1-score  0_0_0_support  \
# 0    0.633333         0.833333             1        0.909091             10
# 1    0.566667         0.434783             1        0.606061             10
# 2    0.333333         0.333333             1        0.500000             10
# 3    0.333333         0.333333             1        0.500000             10
# 4    0.866667         0.769231             1        0.869565             10
#
#    1_0_1_precision  1_0_1_recall  1_0_1_f1-score  1_0_1_support  \
# 0              0.5      1.000000        0.666667              9
# 1              1.0      0.666667        0.800000              9
# 2              0.0      0.000000        0.000000              9
# 3              0.0      0.000000        0.000000              9
# 4              1.0      0.555556        0.714286              9
#
#    2_0_2_precision  ...  weighted avg_0_weighted avg_precision  \
# ...

# %%
for f in df_final_1q["f_loss"].unique():
  df_f_loss = df_final_1q[df_final_1q["f_loss"] == f]
  plt.figure()
  for noise_ in df_f_loss["Noise"].unique():
    df_f_loss_noise = df_f_loss[df_f_loss["Noise"] == noise_]
    plt.plot(df_f_loss_noise["N_layers"], df_f_loss_noise["accuracy_0"],'-o', label = f"noise = {noise_}")
  plt.title(f"f_loss = {f}")
  plt.legend()
  plt.grid()
  plt.show()

# %% [markdown]
# # Resultado entrenamiento 2 qubit - con entrelazamiento

# %%
path_data_full_1q = "/content/drive/MyDrive/Notebook_tesis_def/DATA/resultados_clasificacion_2q_with_entanglement.xlsx"

# %%
df_final_1q = pd.read_excel(path_data_full_1q)
df_final_1q.head()
# Out:
#    accuracy_0  0_0_0_precision  0_0_0_recall  0_0_0_f1-score  0_0_0_support  \
# 0    0.633333         0.769231             1        0.869565             10
# 1    0.566667         0.454545             1        0.625000             10
# 2    0.333333         0.333333             1        0.500000             10
# 3    0.333333         0.333333             1        0.500000             10
# 4    0.933333         0.909091             1        0.952381             10
#
#    1_0_1_precision  1_0_1_recall  1_0_1_f1-score  1_0_1_support  \
# 0         0.529412      1.000000        0.692308              9
# 1         0.875000      0.777778        0.823529              9
# 2         0.000000      0.000000        0.000000              9
# 3         0.000000      0.000000        0.000000              9
# 4         1.000000      0.777778        0.875000              9
#
#    2_0_2_precision  ...  weighted avg_0_weighted avg_precision  \
# ...

# %%
for f in df_final_1q["f_loss"].unique():
  df_f_loss = df_final_1q[df_final_1q["f_loss"] == f]
  plt.figure()
  for noise_ in df_f_loss["Noise"].unique():
    df_f_loss_noise = df_f_loss[df_f_loss["Noise"] == noise_]
    plt.plot(df_f_loss_noise["N_layers"], df_f_loss_noise["accuracy_0"],'-o', label = f"noise = {noise_}")
  plt.title(f"f_loss = {f}")
  plt.legend()
  plt.grid()
  plt.show()

# %% [markdown]
# # Resultado entrenamiento 4 qubit - sin entrelazamiento

# %%
path_data_full_1q = "/content/drive/MyDrive/Notebook_tesis_def/DATA/resultados_clasificacion_4q_wo_entanglement(3).xlsx"

# %%
df_final_1q = pd.read_excel(path_data_full_1q)
df_final_1q.head()
# Out:
#    accuracy_0  0_0_0_precision  0_0_0_recall  0_0_0_f1-score  0_0_0_support  \
# 0    0.633333         0.909091             1        0.952381             10
# 1    0.633333         0.625000             1        0.769231             10
# 2    0.333333         0.333333             1        0.500000             10
# 3    0.333333         0.333333             1        0.500000             10
# 4    0.833333         1.000000             1        1.000000             10
#
#    1_0_1_precision  1_0_1_recall  1_0_1_f1-score  1_0_1_support  \
# 0         0.473684           1.0        0.642857              9
# 1         0.642857           1.0        0.782609              9
# 2         0.000000           0.0        0.000000              9
# 3         0.000000           0.0        0.000000              9
# 4         0.642857           1.0        0.782609              9
#
#    2_0_2_precision  ...  weighted avg_0_weighted avg_precision  \
# ...

# %%
for f in df_final_1q["f_loss"].unique():
  df_f_loss = df_final_1q[df_final_1q["f_loss"] == f]
  plt.figure()
  for noise_ in df_f_loss["Noise"].unique():
    df_f_loss_noise = df_f_loss[df_f_loss["Noise"] == noise_]
    plt.plot(df_f_loss_noise["N_layers"], df_f_loss_noise["accuracy_0"],'-o', label = f"noise = {noise_}")
  plt.title(f"f_loss = {f}")
  plt.legend()
  plt.grid()
  plt.show()

# %% [markdown]
# # Resultado entrenamiento 4 qubit - con entrelazamiento

# %%
path_data_full_1q = "/content/drive/MyDrive/Notebook_tesis_def/DATA/resultados_clasificacion_4q_with_entanglement.xlsx"

# %%
df_final_1q = pd.read_excel(path_data_full_1q)
df_final_1q.head()
# Out:
#    accuracy_0  0_0_0_precision  0_0_0_recall  0_0_0_f1-score  0_0_0_support  \
# 0    0.633333         0.833333             1        0.909091             10
# 1    0.633333         0.625000             1        0.769231             10
# 2    0.333333         0.333333             1        0.500000             10
# 3    0.333333         0.333333             1        0.500000             10
# 4    0.966667         1.000000             1        1.000000             10
#
#    1_0_1_precision  1_0_1_recall  1_0_1_f1-score  1_0_1_support  \
# 0         0.500000           1.0        0.666667              9
# 1         0.642857           1.0        0.782609              9
# 2         0.000000           0.0        0.000000              9
# 3         0.000000           0.0        0.000000              9
# 4         0.900000           1.0        0.947368              9
#
#    2_0_2_precision  ...  weighted avg_0_weighted avg_precision  \
# ...

# %%
for f in df_final_1q["f_loss"].unique():
  df_f_loss = df_final_1q[df_final_1q["f_loss"] == f]
  plt.figure()
  for noise_ in df_f_loss["Noise"].unique():
    df_f_loss_noise = df_f_loss[df_f_loss["Noise"] == noise_]
    plt.plot(df_f_loss_noise["N_layers"], df_f_loss_noise["accuracy_0"],'-o', label = f"noise = {noise_}")
  plt.title(f"f_loss = {f}")
  plt.legend()
  plt.grid()
  plt.show()
