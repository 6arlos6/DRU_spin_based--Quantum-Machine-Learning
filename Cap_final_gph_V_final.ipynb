# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path_data_full = "/content/drive/MyDrive/Notebook_tesis_def/DATA/Save_excel_1q_iris_3_3(18).xlsx"

df_final = pd.read_excel(path_data_full)
df_final.head()
# Out:
#    accuracy_0  0_0_0_precision  0_0_0_recall  0_0_0_f1-score  0_0_0_support  \
# 0    0.155556         0.263158      0.263158        0.263158             19
# 1    0.933333         1.000000      1.000000        1.000000             19
# 2    0.155556         0.263158      0.263158        0.263158             19
# 3    0.733333         0.933333      0.736842        0.823529             19
# 4    0.466667         0.529412      0.473684        0.500000             19
#
#    1_0_1_precision  1_0_1_recall  1_0_1_f1-score  1_0_1_support  \
# 0         0.000000      0.000000        0.000000             13
# 1         0.857143      0.923077        0.888889             13
# 2         0.000000      0.000000        0.000000             13
# 3         0.818182      0.692308        0.750000             13
# 4         0.500000      0.538462        0.518519             13
#
#    2_0_2_precision  ...  Noise  N_qubits  tf_noise  std_noide    B0  B1  \
# ...

# %%
palette = {
    value: sns.color_palette('Set1')[i]
    for i, value in enumerate(df_final['f_loss'].unique())
}

# %% [markdown]
# # ACC

# %% [markdown]
# # 1 qubits

# %%
# ========================================================
path_data_full = "/content/drive/MyDrive/Notebook_tesis_def/DATA/Save_excel_1q_iris_3_3(18).xlsx"
df_final = pd.read_excel(path_data_full)

df_final.rename(columns={'f_loss': '$f_{loss}$'}, inplace=True)
df_final.rename(columns={'T2': '$T_{2}$'}, inplace=True)
df_final.rename(columns={'Noise': '$\zeta_{AD}$'}, inplace=True)
df_final.rename(columns={'std_noide': '$\sigma$'}, inplace=True)
# Definir el diccionario de mapeo
mapeo = {'Renyi_Divergence_v2': 'Renyi Divergence',
         'Trace_Distance_v3': 'Trace Distance',
         'Von_Neumman_Divergence_v2': 'Von Neumman Divergence',
         'fidelity_cost': 'Fidelity Cost'}

# Aplicar el mapeo a la columna 'categorias'
df_final['$f_{loss}$'] = df_final['$f_{loss}$'].map(mapeo)

palette = {
    value: sns.color_palette('Set1')[i]
    for i, value in enumerate(df_final['$f_{loss}$'].unique())
}

# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%



df_final_v2 = df_final[df_final["$T_{2}$"] == 0.000023]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0",
                               hue="$f_{loss}$",
                               size='$\zeta_{AD}$',
                               data=df_final_v2,
                               palette=palette,
                               style = "$\sigma$",
                               sizes=(20, 200))

# Mostrar el plot
# plt.title(f'Accuracy with T2 = {23} u [s]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()

# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
df_final_v2 = df_final[df_final["$T_{2}$"] == 0.000006]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
# , hue='C', size='Tamaño', data=df, palette='Set1', sizes=(20, 200)
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0",
                               hue="$f_{loss}$",size='$\zeta_{AD}$',
                               data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$\sigma$")

# Mostrar el plot
# plt.title(f'Accuracy with T2 = {6} u [s]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
df_final_v2 = df_final[df_final["$\sigma$"] == 0]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ = {0} [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["$\sigma$"] == 0.001]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ =  0.001 [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()


# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["$\sigma$"] == 0.1]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ =  0.1 [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# # 2 qubits

# %%
# ========================================================

path_data_full = "/content/drive/MyDrive/Notebook_tesis_def/DATA/Save_excel_1q_iris_3_3_2q_sin_entre.xlsx"

df_final = pd.read_excel(path_data_full)
df_final.head()



df_final.rename(columns={'f_loss': '$f_{loss}$'}, inplace=True)
df_final.rename(columns={'T2': '$T_{2}$'}, inplace=True)
df_final.rename(columns={'Noise': '$\zeta_{AD}$'}, inplace=True)
df_final.rename(columns={'std_noide': '$\sigma$'}, inplace=True)
# Definir el diccionario de mapeo
mapeo = {'Renyi_Divergence_v2': 'Renyi Divergence',
         'Trace_Distance_v3': 'Trace Distance',
         'Von_Neumman_Divergence_v2': 'Von Neumman Divergence',
         'fidelity_cost': 'Fidelity Cost'}

# Aplicar el mapeo a la columna 'categorias'
df_final['$f_{loss}$'] = df_final['$f_{loss}$'].map(mapeo)



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%



df_final_v2 = df_final[df_final["$T_{2}$"] == 0.000023]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0",
                               hue="$f_{loss}$",
                               size='$\zeta_{AD}$',
                               data=df_final_v2,
                               palette=palette,
                               style = "$\sigma$",
                               sizes=(20, 200))

# Mostrar el plot
# plt.title(f'Accuracy with T2 = {23} u [s]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()

# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
df_final_v2 = df_final[df_final["$T_{2}$"] == 0.000006]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
# , hue='C', size='Tamaño', data=df, palette='Set1', sizes=(20, 200)
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0",
                               hue="$f_{loss}$",size='$\zeta_{AD}$',
                               data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$\sigma$")

# Mostrar el plot
# plt.title(f'Accuracy with T2 = {6} u [s]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
df_final_v2 = df_final[df_final["$\sigma$"] == 0]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ = {0} [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["$\sigma$"] == 0.001]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ =  0.001 [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()


# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["$\sigma$"] == 0.1]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ =  0.1 [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# # 2 qubits con entrelazamiento

# %%
path_data_full = "/content/drive/MyDrive/Notebook_tesis_def/DATA/Save_excel_1q_iris_3_3_2q_con_entrelazamiento.xlsx"

df_final = pd.read_excel(path_data_full)
df_final.head()



df_final.rename(columns={'f_loss': '$f_{loss}$'}, inplace=True)
df_final.rename(columns={'T2': '$T_{2}$'}, inplace=True)
df_final.rename(columns={'Noise': '$\zeta_{AD}$'}, inplace=True)
df_final.rename(columns={'std_noide': '$\sigma$'}, inplace=True)
# Definir el diccionario de mapeo
mapeo = {'Renyi_Divergence_v2': 'Renyi Divergence',
         'Trace_Distance_v3': 'Trace Distance',
         'Von_Neumman_Divergence_v2': 'Von Neumman Divergence',
         'fidelity_cost': 'Fidelity Cost'}

# Aplicar el mapeo a la columna 'categorias'
df_final['$f_{loss}$'] = df_final['$f_{loss}$'].map(mapeo)



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%



df_final_v2 = df_final[df_final["$T_{2}$"] == 0.000023]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0",
                               hue="$f_{loss}$",
                               size='$\zeta_{AD}$',
                               data=df_final_v2,
                               palette=palette,
                               style = "$\sigma$",
                               sizes=(20, 200))

# Mostrar el plot
# plt.title(f'Accuracy with T2 = {23} u [s]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()

# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
df_final_v2 = df_final[df_final["$T_{2}$"] == 0.000006]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
# , hue='C', size='Tamaño', data=df, palette='Set1', sizes=(20, 200)
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0",
                               hue="$f_{loss}$",size='$\zeta_{AD}$',
                               data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$\sigma$")

# Mostrar el plot
# plt.title(f'Accuracy with T2 = {6} u [s]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
df_final_v2 = df_final[df_final["$\sigma$"] == 0]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ = {0} [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["$\sigma$"] == 0.001]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ =  0.001 [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()


# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["$\sigma$"] == 0.1]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ =  0.1 [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# # 4 qubits

# %%
path_data_full = "/content/drive/MyDrive/Notebook_tesis_def/DATA/Save_excel_1q_iris_3_3_4q.xlsx"

df_final = pd.read_excel(path_data_full)
df_final.head()

df_final.rename(columns={'f_loss': '$f_{loss}$'}, inplace=True)
df_final.rename(columns={'T2': '$T_{2}$'}, inplace=True)
df_final.rename(columns={'Noise': '$\zeta_{AD}$'}, inplace=True)
df_final.rename(columns={'std_noide': '$\sigma$'}, inplace=True)
# Definir el diccionario de mapeo
mapeo = {'Renyi_Divergence_v2': 'Renyi Divergence',
         'Trace_Distance_v3': 'Trace Distance',
         'Von_Neumman_Divergence_v2': 'Von Neumman Divergence',
         'fidelity_cost': 'Fidelity Cost'}

# Aplicar el mapeo a la columna 'categorias'
df_final['$f_{loss}$'] = df_final['$f_{loss}$'].map(mapeo)



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%



df_final_v2 = df_final[df_final["$T_{2}$"] == 0.000023]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0",
                               hue="$f_{loss}$",
                               size='$\zeta_{AD}$',
                               data=df_final_v2,
                               palette=palette,
                               style = "$\sigma$",
                               sizes=(20, 200))

# Mostrar el plot
# plt.title(f'Accuracy with T2 = {23} u [s]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()

# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
df_final_v2 = df_final[df_final["$T_{2}$"] == 0.000006]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
# , hue='C', size='Tamaño', data=df, palette='Set1', sizes=(20, 200)
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0",
                               hue="$f_{loss}$",size='$\zeta_{AD}$',
                               data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$\sigma$")

# Mostrar el plot
# plt.title(f'Accuracy with T2 = {6} u [s]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
df_final_v2 = df_final[df_final["$\sigma$"] == 0]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ = {0} [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["$\sigma$"] == 0.001]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ =  0.001 [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()


# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["$\sigma$"] == 0.1]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ =  0.1 [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# # 4 qubits con entrelazamiento

# %%
path_data_full = "/content/drive/MyDrive/Notebook_tesis_def/DATA/Save_excel_1q_iris_3_3_4_con_entrelazamiento.xlsx"

df_final = pd.read_excel(path_data_full)
df_final.head()



df_final.rename(columns={'f_loss': '$f_{loss}$'}, inplace=True)
df_final.rename(columns={'T2': '$T_{2}$'}, inplace=True)
df_final.rename(columns={'Noise': '$\zeta_{AD}$'}, inplace=True)
df_final.rename(columns={'std_noide': '$\sigma$'}, inplace=True)
# Definir el diccionario de mapeo
mapeo = {'Renyi_Divergence_v2': 'Renyi Divergence',
         'Trace_Distance_v3': 'Trace Distance',
         'Von_Neumman_Divergence_v2': 'Von Neumman Divergence',
         'fidelity_cost': 'Fidelity Cost'}

# Aplicar el mapeo a la columna 'categorias'
df_final['$f_{loss}$'] = df_final['$f_{loss}$'].map(mapeo)



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%



df_final_v2 = df_final[df_final["$T_{2}$"] == 0.000023]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0",
                               hue="$f_{loss}$",
                               size='$\zeta_{AD}$',
                               data=df_final_v2,
                               palette=palette,
                               style = "$\sigma$",
                               sizes=(20, 200))

# Mostrar el plot
# plt.title(f'Accuracy with T2 = {23} u [s]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()

# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
df_final_v2 = df_final[df_final["$T_{2}$"] == 0.000006]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
# , hue='C', size='Tamaño', data=df, palette='Set1', sizes=(20, 200)
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0",
                               hue="$f_{loss}$",size='$\zeta_{AD}$',
                               data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$\sigma$")

# Mostrar el plot
# plt.title(f'Accuracy with T2 = {6} u [s]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
df_final_v2 = df_final[df_final["$\sigma$"] == 0]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ = {0} [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["$\sigma$"] == 0.001]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ =  0.001 [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()


# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["$\sigma$"] == 0.1]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="accuracy_0", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ =  0.1 [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# # F1

# %% [markdown]
# weighted avg_0_weighted avg_f1-score

# %% [markdown]
# # 1 qubits

# %%
# ========================================================

path_data_full = "/content/drive/MyDrive/Notebook_tesis_def/DATA/Save_excel_1q_iris_3_3(18).xlsx"

df_final = pd.read_excel(path_data_full)
df_final.head()




df_final.rename(columns={'f_loss': '$f_{loss}$'}, inplace=True)
df_final.rename(columns={'T2': '$T_{2}$'}, inplace=True)
df_final.rename(columns={'Noise': '$\zeta_{AD}$'}, inplace=True)
df_final.rename(columns={'std_noide': '$\sigma$'}, inplace=True)
# Definir el diccionario de mapeo
mapeo = {'Renyi_Divergence_v2': 'Renyi Divergence',
         'Trace_Distance_v3': 'Trace Distance',
         'Von_Neumman_Divergence_v2': 'Von Neumman Divergence',
         'fidelity_cost': 'Fidelity Cost'}

# Aplicar el mapeo a la columna 'categorias'
df_final['$f_{loss}$'] = df_final['$f_{loss}$'].map(mapeo)



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%



df_final_v2 = df_final[df_final["$T_{2}$"] == 0.000023]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score",
                               hue="$f_{loss}$",
                               size='$\zeta_{AD}$',
                               data=df_final_v2,
                               palette=palette,
                               style = "$\sigma$",
                               sizes=(20, 200))

# Mostrar el plot
# plt.title(f'Accuracy with T2 = {23} u [s]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()

# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
df_final_v2 = df_final[df_final["$T_{2}$"] == 0.000006]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
# , hue='C', size='Tamaño', data=df, palette='Set1', sizes=(20, 200)
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score",
                               hue="$f_{loss}$",size='$\zeta_{AD}$',
                               data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$\sigma$")

# Mostrar el plot
# plt.title(f'Accuracy with T2 = {6} u [s]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
df_final_v2 = df_final[df_final["$\sigma$"] == 0]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ = {0} [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["$\sigma$"] == 0.001]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ =  0.001 [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()


# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["$\sigma$"] == 0.1]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ =  0.1 [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# # 2 qubits

# %%
path_data_full = "/content/drive/MyDrive/Notebook_tesis_def/DATA/Save_excel_1q_iris_3_3_2q_sin_entre.xlsx"

df_final = pd.read_excel(path_data_full)
df_final.head()

df_final.rename(columns={'f_loss': '$f_{loss}$'}, inplace=True)
df_final.rename(columns={'T2': '$T_{2}$'}, inplace=True)
df_final.rename(columns={'Noise': '$\zeta_{AD}$'}, inplace=True)
df_final.rename(columns={'std_noide': '$\sigma$'}, inplace=True)
# Definir el diccionario de mapeo
mapeo = {'Renyi_Divergence_v2': 'Renyi Divergence',
         'Trace_Distance_v3': 'Trace Distance',
         'Von_Neumman_Divergence_v2': 'Von Neumman Divergence',
         'fidelity_cost': 'Fidelity Cost'}

# Aplicar el mapeo a la columna 'categorias'
df_final['$f_{loss}$'] = df_final['$f_{loss}$'].map(mapeo)



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%



df_final_v2 = df_final[df_final["$T_{2}$"] == 0.000023]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score",
                               hue="$f_{loss}$",
                               size='$\zeta_{AD}$',
                               data=df_final_v2,
                               palette=palette,
                               style = "$\sigma$",
                               sizes=(20, 200))

# Mostrar el plot
# plt.title(f'Accuracy with T2 = {23} u [s]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()

# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
df_final_v2 = df_final[df_final["$T_{2}$"] == 0.000006]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
# , hue='C', size='Tamaño', data=df, palette='Set1', sizes=(20, 200)
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score",
                               hue="$f_{loss}$",size='$\zeta_{AD}$',
                               data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$\sigma$")

# Mostrar el plot
# plt.title(f'Accuracy with T2 = {6} u [s]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
df_final_v2 = df_final[df_final["$\sigma$"] == 0]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ = {0} [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["$\sigma$"] == 0.001]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ =  0.001 [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()


# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["$\sigma$"] == 0.1]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ =  0.1 [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# # 2 qubits con entrelazamiento

# %%
path_data_full = "/content/drive/MyDrive/Notebook_tesis_def/DATA/Save_excel_1q_iris_3_3_2q_con_entrelazamiento.xlsx"

df_final = pd.read_excel(path_data_full)
df_final.head()


df_final.rename(columns={'f_loss': '$f_{loss}$'}, inplace=True)
df_final.rename(columns={'T2': '$T_{2}$'}, inplace=True)
df_final.rename(columns={'Noise': '$\zeta_{AD}$'}, inplace=True)
df_final.rename(columns={'std_noide': '$\sigma$'}, inplace=True)
# Definir el diccionario de mapeo
mapeo = {'Renyi_Divergence_v2': 'Renyi Divergence',
         'Trace_Distance_v3': 'Trace Distance',
         'Von_Neumman_Divergence_v2': 'Von Neumman Divergence',
         'fidelity_cost': 'Fidelity Cost'}

# Aplicar el mapeo a la columna 'categorias'
df_final['$f_{loss}$'] = df_final['$f_{loss}$'].map(mapeo)



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%



df_final_v2 = df_final[df_final["$T_{2}$"] == 0.000023]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score",
                               hue="$f_{loss}$",
                               size='$\zeta_{AD}$',
                               data=df_final_v2,
                               palette=palette,
                               style = "$\sigma$",
                               sizes=(20, 200))

# Mostrar el plot
# plt.title(f'Accuracy with T2 = {23} u [s]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()

# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
df_final_v2 = df_final[df_final["$T_{2}$"] == 0.000006]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
# , hue='C', size='Tamaño', data=df, palette='Set1', sizes=(20, 200)
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score",
                               hue="$f_{loss}$",size='$\zeta_{AD}$',
                               data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$\sigma$")

# Mostrar el plot
# plt.title(f'Accuracy with T2 = {6} u [s]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
df_final_v2 = df_final[df_final["$\sigma$"] == 0]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ = {0} [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["$\sigma$"] == 0.001]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ =  0.001 [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()


# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["$\sigma$"] == 0.1]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ =  0.1 [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# # 4 qubits

# %%
path_data_full = "/content/drive/MyDrive/Notebook_tesis_def/DATA/Save_excel_1q_iris_3_3_4q.xlsx"

df_final = pd.read_excel(path_data_full)
df_final.head()
df_final.rename(columns={'f_loss': '$f_{loss}$'}, inplace=True)
df_final.rename(columns={'T2': '$T_{2}$'}, inplace=True)
df_final.rename(columns={'Noise': '$\zeta_{AD}$'}, inplace=True)
df_final.rename(columns={'std_noide': '$\sigma$'}, inplace=True)
# Definir el diccionario de mapeo
mapeo = {'Renyi_Divergence_v2': 'Renyi Divergence',
         'Trace_Distance_v3': 'Trace Distance',
         'Von_Neumman_Divergence_v2': 'Von Neumman Divergence',
         'fidelity_cost': 'Fidelity Cost'}

# Aplicar el mapeo a la columna 'categorias'
df_final['$f_{loss}$'] = df_final['$f_{loss}$'].map(mapeo)



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%



df_final_v2 = df_final[df_final["$T_{2}$"] == 0.000023]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score",
                               hue="$f_{loss}$",
                               size='$\zeta_{AD}$',
                               data=df_final_v2,
                               palette=palette,
                               style = "$\sigma$",
                               sizes=(20, 200))

# Mostrar el plot
# plt.title(f'Accuracy with T2 = {23} u [s]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()

# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
df_final_v2 = df_final[df_final["$T_{2}$"] == 0.000006]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
# , hue='C', size='Tamaño', data=df, palette='Set1', sizes=(20, 200)
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score",
                               hue="$f_{loss}$",size='$\zeta_{AD}$',
                               data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$\sigma$")

# Mostrar el plot
# plt.title(f'Accuracy with T2 = {6} u [s]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
df_final_v2 = df_final[df_final["$\sigma$"] == 0]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ = {0} [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["$\sigma$"] == 0.001]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ =  0.001 [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()


# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["$\sigma$"] == 0.1]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ =  0.1 [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# # 4 qubits con entrelazamiento

# %%
path_data_full = "/content/drive/MyDrive/Notebook_tesis_def/DATA/Save_excel_1q_iris_3_3_4_con_entrelazamiento.xlsx"

df_final = pd.read_excel(path_data_full)
df_final.head()

df_final.rename(columns={'f_loss': '$f_{loss}$'}, inplace=True)
df_final.rename(columns={'T2': '$T_{2}$'}, inplace=True)
df_final.rename(columns={'Noise': '$\zeta_{AD}$'}, inplace=True)
df_final.rename(columns={'std_noide': '$\sigma$'}, inplace=True)
# Definir el diccionario de mapeo
mapeo = {'Renyi_Divergence_v2': 'Renyi Divergence',
         'Trace_Distance_v3': 'Trace Distance',
         'Von_Neumman_Divergence_v2': 'Von Neumman Divergence',
         'fidelity_cost': 'Fidelity Cost'}

# Aplicar el mapeo a la columna 'categorias'
df_final['$f_{loss}$'] = df_final['$f_{loss}$'].map(mapeo)



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%



df_final_v2 = df_final[df_final["$T_{2}$"] == 0.000023]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score",
                               hue="$f_{loss}$",
                               size='$\zeta_{AD}$',
                               data=df_final_v2,
                               palette=palette,
                               style = "$\sigma$",
                               sizes=(20, 200))

# Mostrar el plot
# plt.title(f'Accuracy with T2 = {23} u [s]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()

# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
df_final_v2 = df_final[df_final["$T_{2}$"] == 0.000006]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
# , hue='C', size='Tamaño', data=df, palette='Set1', sizes=(20, 200)
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score",
                               hue="$f_{loss}$",size='$\zeta_{AD}$',
                               data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$\sigma$")

# Mostrar el plot
# plt.title(f'Accuracy with T2 = {6} u [s]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
df_final_v2 = df_final[df_final["$\sigma$"] == 0]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ = {0} [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()



# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["$\sigma$"] == 0.001]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ =  0.001 [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()


# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
import matplotlib.pyplot as plt
import seaborn as sns

df_final_v2 = df_final[df_final["$\sigma$"] == 0.1]

# Configurar el estilo de seaborn (opcional)
sns.set(style="whitegrid")

# Crear el scatter plot y asignar colores basados en la columna C
plt.figure(figsize=(8, 6))
scatter_plot = sns.scatterplot(x="num_layers", y="weighted avg_0_weighted avg_f1-score", hue="$f_{loss}$",
                               size='$\zeta_{AD}$', data=df_final_v2, palette=palette, sizes=(20, 200),
                               style = "$T_{2}$")

# Mostrar el plot
# plt.title(f'Accuracy with $\sigma$ =  0.1 [T]')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel("$N_{L}$", fontsize=16)
plt.ylabel("Accuracy", fontsize=16)
plt.ylim(0, 1.1);plt.legend(fontsize=12,bbox_to_anchor=(1.05, 1), loc='upper left' ); plt.xticks(fontsize=14); plt.yticks(fontsize=14)
plt.show()
